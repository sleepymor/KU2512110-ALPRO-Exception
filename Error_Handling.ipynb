# %% [markdown]
# <a href="https://colab.research.google.com/github/sleepymor/KU2512110-ALPRO-Exception/blob/main/Error_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Contoh Code Exception Handling

try:
  # Kode yang mungkin menimbulkan error
  angka1 = int(input("Masukkan angka pertama: "))
  angka2 = int(input("Masukkan angka kedua: "))
  hasil = angka1 / angka2
  print(f"Hasil pembagian: {hasil}")

# except ZeroDivisionError:
#   # Blok ini akan dijalankan jika terjadi ZeroDivisionError
#   print("Error: Tidak bisa melakukan pembagian dengan nol!")

# except ValueError:
#   # Blok ini akan dijalankan jika terjadi ValueError (misal: input bukan angka)
#   print("Error: Masukkan hanya angka!")

# except Exception as e:
#   # Blok ini akan menangani exception lain yang tidak spesifik
#   print(f"Terjadi error lain: {e}")

# finally:
#   # Blok ini akan selalu dijalankan, terlepas dari terjadi atau tidaknya error
#   print("Program selesai.")
# Out:
# Masukkan angka pertama: d
# Error: Masukkan hanya angka!

# %% [markdown]
# Soal 1
#
# Buatlah program yang meminta dua input bilangan dari pengguna, lalu menampilkan hasil pembagian bilangan pertama dengan bilangan kedua.
# Gunakan try dan except untuk menangani kesalahan jika pengguna memasukkan:
# Nilai bukan angka (misal huruf atau simbol)
# Pembagian dengan nol
#
# Contoh:
#
# Masukkan angka pertama: 10
#
# Masukkan angka kedua: 0
#
# Terjadi kesalahan: Tidak bisa membagi dengan nol!
#
#
#
#
# Soal 2
# Buatlah program yang meminta pengguna untuk memasukkan usia mereka. Program harus mencoba mengubah input tersebut menjadi integer, dan jika gagal, tampilkan pesan kesalahan yang sesuai.
# Jika berhasil, tampilkan pesan seperti:
#
# Contoh:
#
# Masukkan usia anda: 21
#
# Usia kamu adalah 21 tahun
#
# Jika gagal:
#
# Input tidak valid! Masukkan angka saja.

# %%
try:
    #terima input angka pertama


    #terima input angka kedua

    hasil = angka1 / angka2
    print(f"Hasil pembagian: {hasil}")

#error jika yang dimasukan bukan angka
except ...:
    print("Terjadi kesalahan: Input harus berupa angka!")

#eror jika yang dimasukkan angka2 adalah 0
except ...:
    print("Terjadi kesalahan: Tidak bisa membagi dengan nol!")

# %%
try:
    #masukkan usia

    print(f"Usia kamu adalah {usia} tahun.")

#error jika yang dimasukkan bukan angka
except ...:
    print("Input tidak valid! Masukkan angka saja.")
